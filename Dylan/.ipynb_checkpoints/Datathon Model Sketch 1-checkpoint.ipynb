# %% [markdown]
# # Exploracion de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

vuelos = 'C:\\Users\\max80\\OneDrive\\Documents\\DATATHON 2024\\Filghts TEC_Valid.csv'
compras = 'C:\\Users\\max80\\OneDrive\\Documents\\DATATHON 2024\\Sales TEC_Valid.csv'

df_vuelos = pd.read_csv(vuelos)
df_compras = pd.read_csv(compras)

n_vuelos = df_vuelos.shape[0]
n_compras = df_compras.shape[0]

vacios_vuelos = df_vuelos.isna()
vacios_vuelos = vacios_vuelos.sum()

vacios_compras = df_compras.isna()
vacios_compras = vacios_compras.sum()

#display(df_vuelos)

# %%
print("La base de vuelos tiene:", n_vuelos,"lineas")
print("La base de compras tiene:", n_compras,"lineas")
# Out:
# La base de vuelos tiene: 245753 lineas
# La base de compras tiene: 2564361 lineas

# %%
print(vacios_vuelos)
# Out:
# Flight_ID                0
# Aeronave             80390
# DepartureStation         1
# ArrivalStation           1
# Destination_Type         1
# Origin_Type              1
# STD                      0
# STA                      0
# Capacity                 0
# Passengers          123525
# Bookings            123525
# dtype: int64

# %%
print(vacios_compras)
# Out:
# Flight_ID      0
# ProductType    0
# ProductName    0
# Quantity       0
# TotalSales     0
# dtype: int64

# %%
total_ID = df_vuelos['Flight_ID'].nunique()
print(total_ID)

ID  = df_vuelos['Flight_ID'].value_counts()
ID = pd.DataFrame(ID)
ID = ID.sort_values(by = 'count', ascending = False)
#display(ID)
# Out:
# 238055

# %%
df_vuelos['STD'] = pd.to_datetime(df_vuelos['STD'])
df_vuelos['Año'] = df_vuelos['STD'].dt.year
df_vuelos['Mes'] = df_vuelos['STD'].dt.month

df_vuelos = df_vuelos.sort_values(by = 'STD', ascending = True)

pasajeros_mes = df_vuelos.groupby(['Año', 'Mes'])['Passengers'].sum()

#plt.figure(figsize=(10, 6))
#pasajeros_mes.plot(marker='o', linestyle='-', color='burlywood', label='Total Pasajeros por mes')

#plt.xlabel('Fecha')
#plt.ylabel('Pasajeros')
#plt.title('Pasajeros 2023')
#plt.legend()
#plt.xticks(rotation=45)
#plt.grid(True)
#plt.tight_layout()
#plt.show()

# %% [markdown]
# # Creacion de base final

# %%
df_final = df_vuelos.dropna()

df_final['Departure'] = df_final['STD'].dt.time
df_final["Route"] = df_final["DepartureStation"] + "+" + df_final["ArrivalStation"]
df_final["Occupation fraction"] = df_final["Passengers"] / df_final["Capacity"]

df_final['STA'] = pd.to_datetime(df_final['STA'])
df_final['Arrival'] = df_final['STA'].dt.time

df_final['Departure'] = pd.to_datetime(df_final['Departure'], format='%H:%M:%S').dt.time
df_final['Arrival'] = pd.to_datetime(df_final['Arrival'], format='%H:%M:%S').dt.time
df_final['departure_minutes'] = df_final['Departure'].apply(lambda x: x.hour * 60 + x.minute)
df_final['arrival_minutes'] = df_final['Arrival'].apply(lambda x: x.hour * 60 + x.minute)

df_final['Duration'] = df_final['arrival_minutes'] - df_final['departure_minutes']
# Out:
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Departure'] = df_final['STD'].dt.time
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Route"] = df_final["DepartureStation"] + "+" + df_final["ArrivalStation"]
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Occupation fraction"] = df_final["Passengers"] / df_final["Capacity"]
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['STA'] = pd.to_datetime(df_final['STA'])
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Arrival'] = df_final['STA'].dt.time
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Departure'] = pd.to_datetime(df_final['Departure'], format='%H:%M:%S').dt.time
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Arrival'] = pd.to_datetime(df_final['Arrival'], format='%H:%M:%S').dt.time
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['departure_minutes'] = df_final['Departure'].apply(lambda x: x.hour * 60 + x.minute)
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['arrival_minutes'] = df_final['Arrival'].apply(lambda x: x.hour * 60 + x.minute)
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\757766087.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Duration'] = df_final['arrival_minutes'] - df_final['departure_minutes']

# %% [markdown]
# # Asignacion de inputs y output

# %%
categorias = df_final[['Route','Departure']]
numericas = df_final[['Mes','Capacity']]

encoder = LabelEncoder()  #Codificador de categorias
categorias = categorias.apply(encoder.fit_transform) #Codificacion

X = pd.concat([pd.DataFrame(numericas), categorias], axis=1) #Inputs array
Y = df_final['Occupation fraction']  #Output

# %% [markdown]
# # Red neuronal de 5 capas y entrenamiento

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=20)  #Particion de los datos de output en entrenamiento y prueba

model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),  
    tf.keras.layers.Dense(32, activation='relu'), 
    tf.keras.layers.Dense(16, activation='relu'),  
    tf.keras.layers.Dense(8, activation='relu'),   
    tf.keras.layers.Dense(4, activation='relu'),  
    tf.keras.layers.Dense(1)                      
])
model.compile(optimizer = 'adam', loss = 'mean_squared_error')   #Compilador del modelo, optimizador y funcion de error
model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))  #Entrenamiento
# Out:
# C:\Users\max80\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.4571 - val_loss: 0.0309
# Epoch 2/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0257 - val_loss: 0.0229
# Epoch 3/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0223 - val_loss: 0.0218
# Epoch 4/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0225 - val_loss: 0.0222
# Epoch 5/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 6/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0221 - val_loss: 0.0215
# Epoch 7/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0219 - val_loss: 0.0213
# Epoch 8/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0219 - val_loss: 0.0209
# Epoch 9/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0212 - val_loss: 0.0209
# Epoch 10/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0214 - val_loss: 0.0209
# Epoch 11/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0212 - val_loss: 0.0212
# Epoch 12/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0212 - val_loss: 0.0214
# Epoch 13/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0213 - val_loss: 0.0212
# Epoch 14/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0212 - val_loss: 0.0207
# Epoch 15/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0209 - val_loss: 0.0208
# Epoch 16/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0209 - val_loss: 0.0218
# Epoch 17/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0207 - val_loss: 0.0209
# Epoch 18/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0208 - val_loss: 0.0207
# Epoch 19/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0207 - val_loss: 0.0206
# Epoch 20/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0205 - val_loss: 0.0203
# Epoch 21/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0209 - val_loss: 0.0207
# Epoch 22/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0210 - val_loss: 0.0209
# Epoch 23/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0207 - val_loss: 0.0209
# Epoch 24/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0205 - val_loss: 0.0207
# Epoch 25/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0206 - val_loss: 0.0207
# Epoch 26/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0208 - val_loss: 0.0206
# Epoch 27/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0205 - val_loss: 0.0204
# Epoch 28/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0210 - val_loss: 0.0205
# Epoch 29/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0209 - val_loss: 0.0204
# Epoch 30/30
# 3044/3044 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 0.0205 - val_loss: 0.0205

# %% [markdown]
# # Prueba de errores con datos conocidos

# %%
prediccion_23 = model.predict(X)
prediccion_23 = prediccion_23.flatten()
df_final['Neurona'] = prediccion_23
# Out:
# 3804/3804 ━━━━━━━━━━━━━━━━━━━━ 3s 753us/step
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\1451501567.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Neurona'] = prediccion_23

# %%
df_final['ERROR'] = (df_final['Occupation fraction'] - df_final['Neurona'])**2
error_medio = df_final['ERROR'].mean()
df_final['Passengers Prediction'] = df_final['Neurona'] * df_final['Capacity']
display(df_final)

print("El error promedio entre las predicciones es del:",error_medio*100,"%")
# Out:
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\3774152266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['ERROR'] = (df_final['Occupation fraction'] - df_final['Neurona'])**2
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\3774152266.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Passengers Prediction'] = df_final['Neurona'] * df_final['Capacity']
#                                Flight_ID Aeronave DepartureStation  \
# 6696    030f35839975b1721e2427db425ef402   XA-VAJ               BM
# 178553  7b9f51daca0f560676d28aee3d5666f7   XA-VAW               BM
# 53258   d4ac6f26a94efea00002147f15d96a41   XA-VIU               BM
# 123223  555496d4217768d1cc276ffbe83235d5   XA-VXF               AT
# 53248   01cb03565042d43a1deafae09eef0ca1   XA-VAN               BM
# ...                                  ...      ...              ...
# 221868  a665d50e95bf905d862563facacbf05a   XA-VXA               AO
# 92561   6dda5bd834419dd5b900408b0f5fd77b   XA-VAU               BM
# 105522  c711d31ee17b65d788d2df7ebde346f1   XA-VBI               AK
# 57082   dc6b4fa09794681fbf19cdd98f5a942e   XA-VIF               BM
# 102919  34771f9eadb3f935f45d3271fa9929ce   XA-VXP               BM
#
#        ArrivalStation     Destination_Type        Origin_Type  \
# 6696               AV  MX Amigos y Familia  Ciudad Fronteriza
# 178553             BA     Ciudad Principal  Ciudad Fronteriza
# 53258              AO     Ciudad Principal  Ciudad Fronteriza
# 123223             AU           Ecoturismo   Ciudad Principal
# 53248              AO     Ciudad Principal  Ciudad Fronteriza
# ...               ...                  ...                ...
# 221868             BM    Ciudad Fronteriza   Ciudad Principal
# 92561              AT     Ciudad Principal  Ciudad Fronteriza
# 105522             AT     Ciudad Principal              Playa
# 57082              AO     Ciudad Principal  Ciudad Fronteriza
# 102919             AT     Ciudad Principal  Ciudad Fronteriza
#
#                        STD                 STA  Capacity  Passengers  ...  \
# 6696   2023-01-02 00:20:00 2023-01-02 05:20:00       186       120.0  ...
# 178553 2023-01-02 00:30:00 2023-01-02 06:00:00       186       170.0  ...
# 53258  2023-01-02 00:35:00 2023-01-02 05:30:00       186       185.0  ...
# 123223 2023-01-02 00:55:00 2023-01-02 02:45:00       240       168.0  ...
# 53248  2023-01-02 01:15:00 2023-01-02 06:10:00       186       165.0  ...
# ...                    ...                 ...       ...         ...  ...
# 221868 2023-12-31 23:00:00 2024-01-01 00:05:00       240       201.0  ...
# 92561  2023-12-31 23:05:00 2024-01-01 04:30:00       186       131.0  ...
# 105522 2023-12-31 23:15:00 2024-01-01 00:45:00       220       217.0  ...
# 57082  2023-12-31 23:45:00 2024-01-01 04:40:00       186       168.0  ...
# 102919 2023-12-31 23:50:00 2024-01-01 05:15:00       240       161.0  ...
#
#         Departure  Route  Occupation fraction   Arrival departure_minutes  \
# 6696     00:20:00  BM+AV             0.645161  05:20:00                20
# 178553   00:30:00  BM+BA             0.913978  06:00:00                30
# 53258    00:35:00  BM+AO             0.994624  05:30:00                35
# 123223   00:55:00  AT+AU             0.700000  02:45:00                55
# 53248    01:15:00  BM+AO             0.887097  06:10:00                75
# ...           ...    ...                  ...       ...               ...
# 221868   23:00:00  AO+BM             0.837500  00:05:00              1380
# 92561    23:05:00  BM+AT             0.704301  04:30:00              1385
# 105522   23:15:00  AK+AT             0.986364  00:45:00              1395
# 57082    23:45:00  BM+AO             0.903226  04:40:00              1425
# 102919   23:50:00  BM+AT             0.670833  05:15:00              1430
#
#         arrival_minutes Duration   Neurona     ERROR  Passengers Prediction
# 6696                320      300  0.807197  0.026256             150.138682
# 178553              360      330  0.798448  0.013347             148.511344
# 53258               330      295  0.797752  0.038759             148.381799
# 123223              165      110  0.891880  0.036818             214.051208
# 53248               370      295  0.757796  0.016719             140.950032
# ...                 ...      ...       ...       ...                    ...
# 221868                5    -1375  0.868148  0.000939             208.355541
# 92561               270    -1115  0.873660  0.028682             162.500732
# 105522               45    -1350  0.967983  0.000338             212.956157
# 57082               280    -1145  0.852098  0.002614             158.490270
# 102919              315    -1115  0.839983  0.028612             201.595860
#
# [121724 rows x 23 columns]
# El error promedio entre las predicciones es del: 2.060046365721051 %

# %% [markdown]
# # Predicción de los pasajeros para 2024

# %%
df_predict = df_vuelos.loc[(df_vuelos['Año'] == 2024) | (df_vuelos['Año'] == 2025)]
df_predict['Departure'] = df_predict['STD'].dt.time
df_predict["Route"] = df_predict["DepartureStation"] + "+" + df_predict["ArrivalStation"]

df_predict['STA'] = pd.to_datetime(df_predict['STA'])
df_predict['Arrival'] = df_predict['STA'].dt.time

df_predict['Time'] = pd.to_datetime(df_predict['Departure'], format='%H:%M:%S').dt.time
df_predict['Arrival'] = pd.to_datetime(df_predict['Arrival'], format='%H:%M:%S').dt.time
df_predict['departure_minutes'] = df_predict['Departure'].apply(lambda x: x.hour * 60 + x.minute)
df_predict['arrival_minutes'] = df_predict['Arrival'].apply(lambda x: x.hour * 60 + x.minute)

df_predict['Duration'] = df_predict['arrival_minutes'] - df_predict['departure_minutes']

categorias_pre = df_predict[['Route','Departure']]
numericas_pre = df_predict[['Mes','Capacity']]

encoder = LabelEncoder()
categorias_pre = categorias_pre.apply(encoder.fit_transform) #Codificacion

X_pre = pd.concat([pd.DataFrame(numericas_pre), categorias_pre], axis=1) #Inputs prediccion
prediccion_pasajeros = model.predict(X_pre)
prediccion_pasajeros = prediccion_pasajeros.flatten()
df_predict['Prediccion de NN'] = prediccion_pasajeros
display(df_predict)
# Out:
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['Departure'] = df_predict['STD'].dt.time
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict["Route"] = df_predict["DepartureStation"] + "+" + df_predict["ArrivalStation"]
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['STA'] = pd.to_datetime(df_predict['STA'])
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['Arrival'] = df_predict['STA'].dt.time
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['Time'] = pd.to_datetime(df_predict['Departure'], format='%H:%M:%S').dt.time
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['Arrival'] = pd.to_datetime(df_predict['Arrival'], format='%H:%M:%S').dt.time
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['departure_minutes'] = df_predict['Departure'].apply(lambda x: x.hour * 60 + x.minute)
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['arrival_minutes'] = df_predict['Arrival'].apply(lambda x: x.hour * 60 + x.minute)
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['Duration'] = df_predict['arrival_minutes'] - df_predict['departure_minutes']
# 3861/3861 ━━━━━━━━━━━━━━━━━━━━ 3s 752us/step
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\2690908038.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['Prediccion de NN'] = prediccion_pasajeros
#                                Flight_ID Aeronave DepartureStation  \
# 4663    5af600e8e3131804971e9764659a4e50   XA-VIY               BM
# 54136   aa14abe062912b5497a400a8f3473407   XA-VBT               BM
# 182265  803b0d7b2c8ae03f9f098eb1686d683a   XA-VXJ               BM
# 9935    479ec62310c8a89c85914816e29e81ec   XA-VAA               BM
# 172070  26a1ddf4c763fc84f7734ef5308cf6de   XA-VAP               BM
# ...                                  ...      ...              ...
# 207139  5090fa2ada3c76da44b40fec78891525      NaN               AJ
# 48659   73345da7fda8556db7922e6e70042a2a      NaN               AT
# 27850   34f7f5945961e1f67642da6677a2af6b      NaN               BA
# 59264   215890ec1900b8158332d8e71e49620f      NaN               AT
# 219381  dcbe4720cadf3043b250259bcd14244f      NaN               AV
#
#        ArrivalStation     Destination_Type          Origin_Type  \
# 4663               AV  MX Amigos y Familia    Ciudad Fronteriza
# 54136              AO     Ciudad Principal    Ciudad Fronteriza
# 182265             BB           Ecoturismo    Ciudad Fronteriza
# 9935               AD  MX Amigos y Familia    Ciudad Fronteriza
# 172070             BA     Ciudad Principal    Ciudad Fronteriza
# ...               ...                  ...                  ...
# 207139             BH                Playa  MX Amigos y Familia
# 48659              AL  MX Amigos y Familia     Ciudad Principal
# 27850              AK                Playa     Ciudad Principal
# 59264              AO     Ciudad Principal     Ciudad Principal
# 219381             BM    Ciudad Fronteriza  MX Amigos y Familia
#
#                        STD                 STA  Capacity  Passengers  ...  \
# 4663   2024-01-01 00:05:00 2024-01-01 05:05:00       186         NaN  ...
# 54136  2024-01-01 00:30:00 2024-01-01 05:25:00       220         NaN  ...
# 182265 2024-01-01 00:55:00 2024-01-01 06:40:00       240         NaN  ...
# 9935   2024-01-01 01:00:00 2024-01-01 05:50:00       186         NaN  ...
# 172070 2024-01-01 01:00:00 2024-01-01 06:15:00       186         NaN  ...
# ...                    ...                 ...       ...         ...  ...
# 207139 2025-02-20 09:50:00 2025-02-20 10:50:00       240         NaN  ...
# 48659  2025-02-20 13:20:00 2025-02-20 15:35:00       220         NaN  ...
# 27850  2025-02-26 12:40:00 2025-02-26 16:05:00       180         NaN  ...
# 59264  2025-02-26 13:35:00 2025-02-26 14:55:00       180         NaN  ...
# 219381 2025-02-28 06:05:00 2025-02-28 07:35:00       240         NaN  ...
#
#          Año  Mes  Departure  Route   Arrival      Time departure_minutes  \
# 4663    2024    1   00:05:00  BM+AV  05:05:00  00:05:00                 5
# 54136   2024    1   00:30:00  BM+AO  05:25:00  00:30:00                30
# 182265  2024    1   00:55:00  BM+BB  06:40:00  00:55:00                55
# 9935    2024    1   01:00:00  BM+AD  05:50:00  01:00:00                60
# 172070  2024    1   01:00:00  BM+BA  06:15:00  01:00:00                60
# ...      ...  ...        ...    ...       ...       ...               ...
# 207139  2025    2   09:50:00  AJ+BH  10:50:00  09:50:00               590
# 48659   2025    2   13:20:00  AT+AL  15:35:00  13:20:00               800
# 27850   2025    2   12:40:00  BA+AK  16:05:00  12:40:00               760
# 59264   2025    2   13:35:00  AT+AO  14:55:00  13:35:00               815
# 219381  2025    2   06:05:00  AV+BM  07:35:00  06:05:00               365
#
#         arrival_minutes  Duration  Prediccion de NN
# 4663                305       300          0.815374
# 54136               325       295          0.772854
# 182265              400       345          0.721435
# 9935                350       290          0.783644
# 172070              375       315          0.782999
# ...                 ...       ...               ...
# 207139              650        60          0.925687
# 48659               935       135          0.963870
# 27850               965       205          0.906244
# 59264               895        80          0.949407
# 219381              455        90          0.843698
#
# [123525 rows x 21 columns]

# %%
df_predict['Passengers'] = df_predict['Prediccion de NN']*df_predict['Capacity']
# Out:
# C:\Users\max80\AppData\Local\Temp\ipykernel_23704\1787274517.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict['Passengers'] = df_predict['Prediccion de NN']*df_predict['Capacity']

# %% [markdown]
# # Asignación de inputs y outputs para cantidad de productos

# %%
df_compras_sum = df_compras[["Flight_ID","ProductType","Quantity"]].groupby(by=["Flight_ID","ProductType"], as_index=False).sum()

mapeo_passengers = dict(zip(df_final["Flight_ID"], df_final["Passengers"]))
df_compras_sum["Passengers"] = df_compras_sum["Flight_ID"].map(mapeo_passengers)

mapeo_route = dict(zip(df_final["Flight_ID"], df_final["Route"]))
df_compras_sum["Route"] = df_compras_sum["Flight_ID"].map(mapeo_route)

mapeo_mes = dict(zip(df_final["Flight_ID"], df_final["Mes"]))
df_compras_sum["Mes"] = df_compras_sum["Flight_ID"].map(mapeo_mes)

mapeo_duration = dict(zip(df_final["Flight_ID"], df_final["Duration"]))
df_compras_sum["Duration"] = df_compras_sum["Flight_ID"].map(mapeo_duration)

df_compras_sum = df_compras_sum.dropna(subset=['Mes'])
df_compras_sum = df_compras_sum.dropna(subset=['Passengers'])
df_compras_sum = df_compras_sum.dropna(subset=['Duration'])
df_compras_sum = df_compras_sum.astype({'Mes': 'int64','Passengers': 'int64', 'Duration': 'int64'})
display(df_compras_sum)
# Out:
#                                Flight_ID  ProductType  Quantity  Passengers  \
# 0       00004a718edba9d9ef878d08f02ae057      Botanas        13         174
# 1       00004a718edba9d9ef878d08f02ae057     Galletas         2         174
# 2       00004a718edba9d9ef878d08f02ae057      Licores         1         174
# 3       00004a718edba9d9ef878d08f02ae057  Perecederos         4         174
# 4       00004a718edba9d9ef878d08f02ae057    Refrescos        16         174
# ...                                  ...          ...       ...         ...
# 777944  ffff881a59bc5274e97ea3c4de344e05      Botanas         2         162
# 777945  ffff881a59bc5274e97ea3c4de344e05     Galletas         1         162
# 777946  ffff881a59bc5274e97ea3c4de344e05  Perecederos         3         162
# 777947  ffff881a59bc5274e97ea3c4de344e05    Refrescos         3         162
# 777948  ffff881a59bc5274e97ea3c4de344e05     Specials         2         162
#
#         Route  Mes  Duration
# 0       AL+AT   12       135
# 1       AL+AT   12       135
# 2       AL+AT   12       135
# 3       AL+AT   12       135
# 4       AL+AT   12       135
# ...       ...  ...       ...
# 777944  BH+AO    3       150
# 777945  BH+AO    3       150
# 777946  BH+AO    3       150
# 777947  BH+AO    3       150
# 777948  BH+AO    3       150
#
# [748425 rows x 7 columns]

# %%
categorys_products_2023 = df_compras_sum[['Route','ProductType']]
numerics_products_2023 = df_compras_sum[['Mes','Passengers','Duration']]

categorys_products_2023 = categorys_products_2023.apply(encoder.fit_transform)

X_products_2023 = pd.concat([pd.DataFrame(numerics_products_2023), categorys_products_2023], axis=1) #Inputs array
Y_products_2023 = df_compras_sum['Quantity']  #Output

# %% [markdown]
# # Modelo 2

# %%
X_train_product, X_test_product, y_train_product, y_test_product = train_test_split(X_products_2023, Y_products_2023, test_size=0.2, random_state=20)  #Particion de los datos de output en entrenamiento y prueba

model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(80, activation='relu', input_shape=(X_train_product.shape[1],)),  
    tf.keras.layers.Dense(40, activation='relu'), 
    tf.keras.layers.Dense(20, activation='relu'),  
    tf.keras.layers.Dense(10, activation='relu'),   
    tf.keras.layers.Dense(5, activation='relu'),  
    tf.keras.layers.Dense(1)                      
])
model_2.compile(optimizer = 'adam', loss = 'mean_squared_error')   #Compilador del modelo, optimizador y funcion de error
model_2.fit(X_train_product, y_train_product, epochs=30, batch_size=32, validation_data=(X_test_product, y_test_product))
# Out:
# Epoch 1/30
# C:\Users\max80\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 26s 1ms/step - loss: 123.4886 - val_loss: 105.1981
# Epoch 2/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 106.8070 - val_loss: 104.7740
# Epoch 3/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 106.1057 - val_loss: 103.0536
# Epoch 4/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 105.0676 - val_loss: 102.1546
# Epoch 5/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 103.3505 - val_loss: 93.3488
# Epoch 6/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 92.1568 - val_loss: 88.2496
# Epoch 7/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 86.1741 - val_loss: 82.4839
# Epoch 8/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 84.1016 - val_loss: 80.8461
# Epoch 9/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 24s 1ms/step - loss: 82.6932 - val_loss: 85.4640
# Epoch 10/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 81.6723 - val_loss: 82.4017
# Epoch 11/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 81.1673 - val_loss: 81.3894
# Epoch 12/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 81.5016 - val_loss: 79.8832
# Epoch 13/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 80.5739 - val_loss: 83.1490
# Epoch 14/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 79.1564 - val_loss: 82.0324
# Epoch 15/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 80.0235 - val_loss: 77.9324
# Epoch 16/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 77.0324 - val_loss: 76.6691
# Epoch 17/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 80.2226 - val_loss: 73.1820
# Epoch 18/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 76.1189 - val_loss: 77.7336
# Epoch 19/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 75.9257 - val_loss: 82.2661
# Epoch 20/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 76.3468 - val_loss: 80.9879
# Epoch 21/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 73.8526 - val_loss: 73.5136
# Epoch 22/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 78.7810 - val_loss: 64.3603
# Epoch 23/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 74.3607 - val_loss: 100.5708
# Epoch 24/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 98.4535 - val_loss: 70.8469
# Epoch 25/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 76.3324 - val_loss: 64.8579
# Epoch 26/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 79.7279 - val_loss: 69.3203
# Epoch 27/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 70.7382 - val_loss: 72.8096
# Epoch 28/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 76.2233 - val_loss: 83.6532
# Epoch 29/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 83.9056 - val_loss: 80.4161
# Epoch 30/30
# 18711/18711 ━━━━━━━━━━━━━━━━━━━━ 25s 1ms/step - loss: 79.4580 - val_loss: 72.8781
