# %%
import pandas as pd

# %%
# Import datasets
df_vuelos = pd.read_csv("D:/Documentos/Python Scripts/Datathon 2024/Filghts TEC_Valid.csv")
df_ventas = pd.read_csv("D:/Documentos/Python Scripts/Datathon 2024/Sales TEC_Valid.csv")

# %%
# Convert date strings to datetime objects, then sort dataframe by departure date
df_vuelos["STD"] = pd.to_datetime(df_vuelos["STD"])
df_vuelos["STA"] = pd.to_datetime(df_vuelos["STA"])

# df_ventas["STD"] = pd.to_datetime(df_ventas["STD"])
# df_ventas["STA"] = pd.to_datetime(df_ventas["STA"])

display(df_ventas)
# Out:
#                                 Flight_ID ProductType  \
# 0        a05290288259526edd3601160b10e1de     Botanas
# 1        08f6f97437df8db101b050f1110be656     Licores
# 2        4e09c949826a77207868412baeff6d30     Licores
# 3        c3e1568fe46c68d3174681d322d412b3     Licores
# 4        7396e43fb94caca87add7bb1f1611e7e     Vivabus
# ...                                   ...         ...
# 2564356  638cf1904f936c50aea4a6f123ee07cf     Licores
# 2564357  04c5a19b8382a888d5c4c7b4932e783e     Licores
# 2564358  0291f6b201d2b24717a8ed7ca04f2d90     Licores
# 2564359  a10e3ac614fd434d6312897e07727c08     Licores
# 2564360  3f53b6ab66d674c6ecec9ebb5d040460     Licores
#
#                             ProductName  Quantity  TotalSales
# 0                   Carne Seca Habanero         1        55.0
# 1                         Jw Red Label          2       240.0
# 2                         Jack And Coke         8       576.0
# 3                          Jw Red Label         2       240.0
# 4        Vivabus_Gdl.-Nvo. C. Camionera         4       320.0
# ...                                 ...       ...         ...
# 2564356       Vino Tinto Sangre De Toro         1       155.0
# 2564357       Vino Tinto Sangre De Toro         1       155.0
# 2564358       Vino Tinto Sangre De Toro         1       155.0
# 2564359       Vino Tinto Sangre De Toro         1       155.0
# 2564360       Vino Tinto Sangre De Toro         1       155.0
#
# [2564361 rows x 5 columns]

# %%
list(df_ventas["ProductType"].unique())
# Out:
# ['Botanas',
#  'Licores',
#  'Vivabus',
#  'Transportaciones CUN',
#  'Galletas',
#  'Specials',
#  'Bebidas Calientes',
#  'COMBOS CREW',
#  'Hertz.',
#  'OFERTAS ',
#  'Transportaciones MTY',
#  'Transportaciones TLC',
#  'VIVA PLAY',
#  'VIVA Taxis',
#  'Antros',
#  'VivaTransfer',
#  'Alimentos Charter',
#  'Perecederos',
#  'Refrescos',
#  'Sopas',
#  'Lacteos']

# %%
df_ventas[["Flight_ID","Quantity","TotalSales"]].groupby("Flight_ID").sum()
# Out:
#                                   Quantity  TotalSales
# Flight_ID
# 00004a718edba9d9ef878d08f02ae057        50      2028.0
# 0000cd79c0c3a9c309df6064dcacaeea        54      2021.0
# 000163f0df9cbfc35c4c06645ec512f6         6       417.0
# 00017be73003a570dd426b155762769c       158      7189.0
# 0001a43836c338f8d8650aefb11672c9       142      7162.0
# ...                                    ...         ...
# fffe47f84ecc55da94b2907a7317dd12       133      4754.0
# fffe4a9c19ae2320e76f02939fdff957        79      3441.0
# ffff138536f249f69340e0a8336f94a4       107      4368.0
# ffff782f2ae79e385a016c00fbd994b8        49      2686.0
# ffff881a59bc5274e97ea3c4de344e05        14       666.0
#
# [108964 rows x 2 columns]

# %%
df_ventas[ df_ventas["Flight_ID"] == "00004a718edba9d9ef878d08f02ae057" ]
# Out:
#                                 Flight_ID  ProductType  \
# 49275    00004a718edba9d9ef878d08f02ae057      Botanas
# 114303   00004a718edba9d9ef878d08f02ae057      Licores
# 145393   00004a718edba9d9ef878d08f02ae057     Specials
# 471401   00004a718edba9d9ef878d08f02ae057    Refrescos
# 610388   00004a718edba9d9ef878d08f02ae057      Botanas
# 652690   00004a718edba9d9ef878d08f02ae057     Specials
# 720334   00004a718edba9d9ef878d08f02ae057    Refrescos
# 1011100  00004a718edba9d9ef878d08f02ae057    Refrescos
# 1020167  00004a718edba9d9ef878d08f02ae057      Botanas
# 1236877  00004a718edba9d9ef878d08f02ae057    Refrescos
# 1315778  00004a718edba9d9ef878d08f02ae057      Botanas
# 1656964  00004a718edba9d9ef878d08f02ae057      Botanas
# 1837543  00004a718edba9d9ef878d08f02ae057      Botanas
# 2006550  00004a718edba9d9ef878d08f02ae057     Galletas
# 2063846  00004a718edba9d9ef878d08f02ae057        Sopas
# 2111901  00004a718edba9d9ef878d08f02ae057     Specials
# 2128160  00004a718edba9d9ef878d08f02ae057        Sopas
# 2207281  00004a718edba9d9ef878d08f02ae057  Perecederos
# 2312306  00004a718edba9d9ef878d08f02ae057    Refrescos
# 2535148  00004a718edba9d9ef878d08f02ae057      Botanas
# 2555960  00004a718edba9d9ef878d08f02ae057  Perecederos
#
#                      ProductName  Quantity  TotalSales
# 49275             Luxury Nut Mix         1        55.0
# 114303                  Xx Lager         1        72.0
# 145393               Combo Snack         8       -56.0
# 471401                    Sprite         3       144.0
# 610388             Doritos Nacho         1        49.0
# 652690            Combo Aventura         1       -12.0
# 720334           Jugo De Manzana         1        42.0
# 1011100            Jugo De Mango         2        84.0
# 1020167            Ruffles Queso         4       196.0
# 1236877      Agua Natural 600 Ml         4       192.0
# 1315778  Frutos Secos Enchilados         1        55.0
# 1656964         Nishikawa Salado         1        45.0
# 1837543       Cheetos Flamin Hot         1        49.0
# 2006550                   Chokis         2        90.0
# 2063846               Nissin Res         2        90.0
# 2111901              Super Combo         2       -56.0
# 2128160             Nissin Fuego         1        45.0
# 2207281           Panini Clasico         3       345.0
# 2312306        Coca Cola Regular         6       288.0
# 2535148      Sabritas Originales         4       196.0
# 2555960   Cuerno Clasico De Pavo         1       115.0

# %%
df_vuelos[ df_vuelos["Flight_ID"] == "00004a718edba9d9ef878d08f02ae057" ]
# Out:
#                               Flight_ID Aeronave DepartureStation  \
# 82515  00004a718edba9d9ef878d08f02ae057   XA-VYD               AL
#
#       ArrivalStation  Destination_Type          Origin_Type  \
# 82515             AT  Ciudad Principal  MX Amigos y Familia
#
#                       STD                 STA  Capacity  Passengers  Bookings
# 82515 2023-12-18 16:20:00 2023-12-18 18:35:00       180       174.0     106.0

# %%
df_vuelos_2 = df_vuelos.dropna()

# Factores que influencian la venta:
# - Factor de ocupación (OccupationFactor)
# - Origen / Destino del vuelo (Origin_Type, Destination_Type)
# - Duración del vuelo (FlightDuration)
# - Horario del vuelo (Time)
# - Temporada (Month)

df_vuelos_2["OccupationFactor"] = df_vuelos_2["Passengers"] / df_vuelos_2["Capacity"]
df_vuelos_2["FlightDuration"] = df_vuelos_2["STA"] - df_vuelos_2["STD"]
df_vuelos_2["Month"] = df_vuelos_2["STD"].dt.month
df_vuelos_2["Time"] = df_vuelos_2["STD"].dt.time

display(df_vuelos_2)
# Out:
# C:\Users\missa\AppData\Local\Temp\ipykernel_30352\3514370108.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vuelos_2["OccupationFactor"] = df_vuelos_2["Passengers"] / df_vuelos_2["Capacity"]
# C:\Users\missa\AppData\Local\Temp\ipykernel_30352\3514370108.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vuelos_2["FlightDuration"] = (df_vuelos_2["STA"] - df_vuelos_2["STD"])
# C:\Users\missa\AppData\Local\Temp\ipykernel_30352\3514370108.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vuelos_2["Month"] = df_vuelos_2["STD"].dt.month
#                                Flight_ID Aeronave DepartureStation  \
# 0       ab954014077430bd842cfa305a55c0f8   XA-VBY               AT
# 1       efd86c996035dacdca7a0ccb2560dda1   XA-VIX               BM
# 3       dd0fad3248951d2f71d63e6279aeaa4b   XA-VBW               AW
# 4       d0987ee648eea254063bfe2b39571b67   XA-VAP               BA
# 5       3b5df8805161ea827d2f2e4298c38e06   XA-VBY               AJ
# ...                                  ...      ...              ...
# 245718  d9ef769565064b1ff1ad90d6d18f69cb   XA-VYF               AO
# 245745  598035669a4f0fa2ce1207977932df9e   XA-VAI               AW
# 245747  90d2cab80b7700b5d854ae393678144b   XA-VYA               BA
# 245748  cc7c1c5e6fd132fd0bdab3a35aac33c0   XA-VBK               BM
# 245750  9c8970e9836d9c5ef9415bfa93c3f408   XA-VAC               AT
#
#        ArrivalStation     Destination_Type          Origin_Type  \
# 0                  AZ    Ciudad Fronteriza     Ciudad Principal
# 1                  AV  MX Amigos y Familia    Ciudad Fronteriza
# 3                  AS  MX Amigos y Familia     Ciudad Principal
# 4                  AB                Playa     Ciudad Principal
# 5                  AR                Playa  MX Amigos y Familia
# ...               ...                  ...                  ...
# 245718             BT                Playa     Ciudad Principal
# 245745             BT                Playa     Ciudad Principal
# 245747             BT                Playa     Ciudad Principal
# 245748             BT                Playa    Ciudad Fronteriza
# 245750             BT                Playa     Ciudad Principal
#
#                        STD                 STA  Capacity  Passengers  \
# 0      2023-10-19 11:40:00 2023-10-19 14:25:00       240       229.0
# 1      2023-07-03 00:55:00 2023-07-03 04:55:00       186       197.0
# 3      2023-06-26 15:15:00 2023-06-26 15:55:00       220       200.0
# 4      2023-02-10 08:40:00 2023-02-10 09:50:00       186       162.0
# 5      2023-09-07 17:10:00 2023-09-07 18:05:00       240       183.0
# ...                    ...                 ...       ...         ...
# 245718 2023-12-26 06:20:00 2023-12-26 10:10:00       180       166.0
# 245745 2023-12-28 10:25:00 2023-12-28 13:50:00       180       142.0
# 245747 2023-12-23 11:45:00 2023-12-23 15:00:00       180       156.0
# 245748 2023-12-29 07:30:00 2023-12-29 14:50:00       240       189.0
# 245750 2023-12-22 12:50:00 2023-12-22 16:10:00       180       163.0
#
#         Bookings  OccupationFactor  FlightDuration  Month
# 0          157.0          0.954167 0 days 02:45:00     10
# 1          109.0          1.059140 0 days 04:00:00      7
# 3          142.0          0.909091 0 days 00:40:00      6
# 4           90.0          0.870968 0 days 01:10:00      2
# 5          125.0          0.762500 0 days 00:55:00      9
# ...          ...               ...             ...    ...
# 245718      89.0          0.922222 0 days 03:50:00     12
# 245745      54.0          0.788889 0 days 03:25:00     12
# 245747      61.0          0.866667 0 days 03:15:00     12
# 245748      86.0          0.787500 0 days 07:20:00     12
# 245750      95.0          0.905556 0 days 03:20:00     12
#
# [121724 rows x 14 columns]
