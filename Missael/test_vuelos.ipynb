# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import datasets
df_vuelos = pd.read_csv("D:/Documentos/Python Scripts/Datathon 2024/Filghts TEC_Valid.csv")
df_ventas = pd.read_csv("D:/Documentos/Python Scripts/Datathon 2024/Sales TEC_Valid.csv")

# %%
# Convert date strings to datetime objects, then sort dataframe by departure date
df_vuelos["STD"] = pd.to_datetime(df_vuelos["STD"])
df_vuelos["STA"] = pd.to_datetime(df_vuelos["STA"])

df_vuelos = df_vuelos.sort_values(by="STD")

# Filter only data where Passengers and Bookings are not NaN (this is the training data)
df_vuelos_1 = df_vuelos[ df_vuelos["Passengers"].notna() ]
df_vuelos_2 = df_vuelos_1.dropna()
display(df_vuelos_2)
# Out:
#                                Flight_ID Aeronave DepartureStation  \
# 6696    030f35839975b1721e2427db425ef402   XA-VAJ               BM
# 178553  7b9f51daca0f560676d28aee3d5666f7   XA-VAW               BM
# 53258   d4ac6f26a94efea00002147f15d96a41   XA-VIU               BM
# 123223  555496d4217768d1cc276ffbe83235d5   XA-VXF               AT
# 53248   01cb03565042d43a1deafae09eef0ca1   XA-VAN               BM
# ...                                  ...      ...              ...
# 221868  a665d50e95bf905d862563facacbf05a   XA-VXA               AO
# 92561   6dda5bd834419dd5b900408b0f5fd77b   XA-VAU               BM
# 105522  c711d31ee17b65d788d2df7ebde346f1   XA-VBI               AK
# 57082   dc6b4fa09794681fbf19cdd98f5a942e   XA-VIF               BM
# 102919  34771f9eadb3f935f45d3271fa9929ce   XA-VXP               BM
#
#        ArrivalStation     Destination_Type        Origin_Type  \
# 6696               AV  MX Amigos y Familia  Ciudad Fronteriza
# 178553             BA     Ciudad Principal  Ciudad Fronteriza
# 53258              AO     Ciudad Principal  Ciudad Fronteriza
# 123223             AU           Ecoturismo   Ciudad Principal
# 53248              AO     Ciudad Principal  Ciudad Fronteriza
# ...               ...                  ...                ...
# 221868             BM    Ciudad Fronteriza   Ciudad Principal
# 92561              AT     Ciudad Principal  Ciudad Fronteriza
# 105522             AT     Ciudad Principal              Playa
# 57082              AO     Ciudad Principal  Ciudad Fronteriza
# 102919             AT     Ciudad Principal  Ciudad Fronteriza
#
#                        STD                 STA  Capacity  Passengers  Bookings
# 6696   2023-01-02 00:20:00 2023-01-02 05:20:00       186       120.0      68.0
# 178553 2023-01-02 00:30:00 2023-01-02 06:00:00       186       170.0      99.0
# 53258  2023-01-02 00:35:00 2023-01-02 05:30:00       186       185.0      89.0
# 123223 2023-01-02 00:55:00 2023-01-02 02:45:00       240       168.0     118.0
# 53248  2023-01-02 01:15:00 2023-01-02 06:10:00       186       165.0      92.0
# ...                    ...                 ...       ...         ...       ...
# 221868 2023-12-31 23:00:00 2024-01-01 00:05:00       240       201.0      90.0
# 92561  2023-12-31 23:05:00 2024-01-01 04:30:00       186       131.0      81.0
# 105522 2023-12-31 23:15:00 2024-01-01 00:45:00       220       217.0     126.0
# 57082  2023-12-31 23:45:00 2024-01-01 04:40:00       186       168.0      75.0
# 102919 2023-12-31 23:50:00 2024-01-01 05:15:00       240       161.0     116.0
#
# [121724 rows x 11 columns]

# %%
df_vuelos_3 = df_vuelos[ df_vuelos["Passengers"].isna() ]
display(df_vuelos_3)
# Out:
#                                Flight_ID Aeronave DepartureStation  \
# 4663    5af600e8e3131804971e9764659a4e50   XA-VIY               BM
# 54136   aa14abe062912b5497a400a8f3473407   XA-VBT               BM
# 182265  803b0d7b2c8ae03f9f098eb1686d683a   XA-VXJ               BM
# 9935    479ec62310c8a89c85914816e29e81ec   XA-VAA               BM
# 172070  26a1ddf4c763fc84f7734ef5308cf6de   XA-VAP               BM
# ...                                  ...      ...              ...
# 207139  5090fa2ada3c76da44b40fec78891525      NaN               AJ
# 48659   73345da7fda8556db7922e6e70042a2a      NaN               AT
# 27850   34f7f5945961e1f67642da6677a2af6b      NaN               BA
# 59264   215890ec1900b8158332d8e71e49620f      NaN               AT
# 219381  dcbe4720cadf3043b250259bcd14244f      NaN               AV
#
#        ArrivalStation     Destination_Type          Origin_Type  \
# 4663               AV  MX Amigos y Familia    Ciudad Fronteriza
# 54136              AO     Ciudad Principal    Ciudad Fronteriza
# 182265             BB           Ecoturismo    Ciudad Fronteriza
# 9935               AD  MX Amigos y Familia    Ciudad Fronteriza
# 172070             BA     Ciudad Principal    Ciudad Fronteriza
# ...               ...                  ...                  ...
# 207139             BH                Playa  MX Amigos y Familia
# 48659              AL  MX Amigos y Familia     Ciudad Principal
# 27850              AK                Playa     Ciudad Principal
# 59264              AO     Ciudad Principal     Ciudad Principal
# 219381             BM    Ciudad Fronteriza  MX Amigos y Familia
#
#                        STD                 STA  Capacity  Passengers  Bookings
# 4663   2024-01-01 00:05:00 2024-01-01 05:05:00       186         NaN       NaN
# 54136  2024-01-01 00:30:00 2024-01-01 05:25:00       220         NaN       NaN
# 182265 2024-01-01 00:55:00 2024-01-01 06:40:00       240         NaN       NaN
# 9935   2024-01-01 01:00:00 2024-01-01 05:50:00       186         NaN       NaN
# 172070 2024-01-01 01:00:00 2024-01-01 06:15:00       186         NaN       NaN
# ...                    ...                 ...       ...         ...       ...
# 207139 2025-02-20 09:50:00 2025-02-20 10:50:00       240         NaN       NaN
# 48659  2025-02-20 13:20:00 2025-02-20 15:35:00       220         NaN       NaN
# 27850  2025-02-26 12:40:00 2025-02-26 16:05:00       180         NaN       NaN
# 59264  2025-02-26 13:35:00 2025-02-26 14:55:00       180         NaN       NaN
# 219381 2025-02-28 06:05:00 2025-02-28 07:35:00       240         NaN       NaN
#
# [123525 rows x 11 columns]

# %%
# Calculate average number of Passengers and Bookings each month
df_v_m = df_vuelos_1
df_v_m["Month"] = df_v_m["STD"].dt.month    # Calculate months
df_month_avg = df_v_m[["Month","Passengers","Bookings"]].groupby("Month", as_index=False).mean().round()
# df_month_avg = df_vuelos_1[["Passengers","Bookings"]].groupby( by=df_vuelos_1["STD"].dt.month, as_index=False ).mean().round()
df_month_avg = df_month_avg.rename(columns={"Passengers":"Mean Passengers","Bookings":"Mean bookings"})
display(df_month_avg)
# Out:
# C:\Users\missa\AppData\Local\Temp\ipykernel_12488\3815676536.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v_m["Month"] = df_v_m["STD"].dt.month    # Calculate months
#     Month  Mean Passengers  Mean bookings
# 0       1            174.0          109.0
# 1       2            177.0          114.0
# 2       3            181.0          116.0
# 3       4            185.0          112.0
# 4       5            185.0          117.0
# 5       6            185.0          115.0
# 6       7            191.0          110.0
# 7       8            187.0          109.0
# 8       9            182.0          117.0
# 9      10            188.0          118.0
# 10     11            185.0          117.0
# 11     12            181.0          111.0

# %%
# Determine keys of departure and arrival stations
# f = lambda x: [x, len(x)]
# print(f(df_vuelos_2.sort_values(by="DepartureStation")["DepartureStation"].unique()))
# print(df_vuelos_2.sort_values(by="ArrivalStation")["ArrivalStation"].unique())

# df_vuelos_2[ df_vuelos_2["DepartureStation"] == 'BM' ][ df_vuelos_2["ArrivalStation"] == 'AV' ]

# print(41 * 40)
df_vuelos_2["Time"] = df_vuelos_2["STD"].dt.time
# df_vuelos_2[(df_vuelos_2["DepartureStation"] == "AB") & (df_vuelos_2["ArrivalStation"] == "AK")][["DepartureStation","ArrivalStation","STD","Time","Capacity"]].sort_values(by="ArrivalStation")
# df_vuelos_2[(df_vuelos_2["DepartureStation"] == "AB") & (df_vuelos_2["ArrivalStation"] == "AK")].sort_values("Time")["Time"].unique()

dep_arr_codes = list(df_vuelos_2.sort_values(by="DepartureStation")["DepartureStation"].unique())
df_pairs = {"Route":[],"Count":[],"Times":[]}
for k1 in dep_arr_codes:
    for k2 in dep_arr_codes:
        if k1 != k2:
            dfx = df_vuelos_2[(df_vuelos_2["DepartureStation"]==k1) & (df_vuelos_2["ArrivalStation"]==k2)]
            c = len( dfx )
            t = sorted(dfx["STD"].dt.time.unique())
            
            if c > 0:
                df_pairs["Route"].append(k1 + " => " + k2)
                df_pairs["Count"].append(c)
                df_pairs["Times"].append(t)
        # else:
        #     continue
        
        # print(df_pairs)
        
df_pairs = pd.DataFrame(df_pairs)
# print(df_pairs)
# Out:
# C:\Users\missa\AppData\Local\Temp\ipykernel_12488\3639792489.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vuelos_2["Time"] = df_vuelos_2["STD"].dt.time

# %%
print(df_pairs)
# Out:
#         Route  Count                                              Times
# 0    AB => AK     86  [08:35:00, 08:50:00, 08:55:00, 09:15:00, 14:20...
# 1    AB => AT    246           [17:35:00, 17:45:00, 17:55:00, 18:50:00]
# 2    AB => AW    125  [08:35:00, 08:40:00, 09:00:00, 10:45:00, 11:20...
# 3    AB => BA    115  [07:25:00, 10:10:00, 10:15:00, 10:20:00, 10:30...
# 4    AC => AW      2                               [01:30:00, 23:30:00]
# ..        ...    ...                                                ...
# 278  BT => AO      7                                         [10:50:00]
# 279  BT => AT     30                                         [16:55:00]
# 280  BT => AW     25  [10:25:00, 11:50:00, 13:15:00, 14:10:00, 14:35...
# 281  BT => BA     24                     [11:55:00, 13:55:00, 15:55:00]
# 282  BT => BM      7                                         [15:35:00]
#
# [283 rows x 3 columns]

# %%
dep_arr_codes = list(df_vuelos_3.sort_values(by="DepartureStation")["DepartureStation"].unique())
df_pairs_2 = {"Route":[],"Count":[],"Times":[]}
for k1 in dep_arr_codes:
    for k2 in dep_arr_codes:
        if k1 != k2:
            dfx = df_vuelos_3[(df_vuelos_3["DepartureStation"]==k1) & (df_vuelos_3["ArrivalStation"]==k2)]
            c = len( dfx )
            t = sorted(dfx["STD"].dt.time.unique())
            
            if c > 0:
                df_pairs_2["Route"].append(k1 + " => " + k2)
                df_pairs_2["Count"].append(c)
                df_pairs_2["Times"].append(t)
        # else:
        #     continue
        
        # print(df_pairs_2)
        
df_pairs_2 = pd.DataFrame(df_pairs_2)

# %%
print(df_pairs_2)
# Out:
#         Route  Count                                              Times
# 0    AB => AK      2                                         [20:45:00]
# 1    AB => AT      7           [07:50:00, 17:50:00, 17:55:00, 18:00:00]
# 2    AB => AW      5           [08:25:00, 09:40:00, 15:30:00, 20:30:00]
# 3    AB => BA    139  [10:15:00, 10:20:00, 10:35:00, 10:55:00, 11:00...
# 4    AC => BN      1                                         [01:30:00]
# ..        ...    ...                                                ...
# 295  BT => AO    156           [10:35:00, 10:40:00, 10:50:00, 10:55:00]
# 296  BT => AT     47           [16:25:00, 16:40:00, 16:55:00, 17:05:00]
# 297  BT => AW    345  [10:25:00, 11:45:00, 12:05:00, 13:30:00, 13:40...
# 298  BT => BA    583  [12:00:00, 13:50:00, 15:00:00, 15:15:00, 15:25...
# 299  BT => BM      9                     [13:20:00, 15:35:00, 16:00:00]
#
# [300 rows x 3 columns]

# %%
df_final = df_vuelos_2
df_final["Route"] = df_final["DepartureStation"] + " => " + df_final["ArrivalStation"]
df_final["Month"] = df_final["STD"].dt.month
df_final["Occupation fraction"] = df_final["Passengers"] / df_final["Capacity"]
display(df_final)
# Out:
# C:\Users\missa\AppData\Local\Temp\ipykernel_12488\4056178946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Route"] = df_final["DepartureStation"] + " => " + df_final["ArrivalStation"]
# C:\Users\missa\AppData\Local\Temp\ipykernel_12488\4056178946.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Month"] = df_final["STD"].dt.month
# C:\Users\missa\AppData\Local\Temp\ipykernel_12488\4056178946.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Occupation fraction"] = df_final["Passengers"] / df_final["Capacity"]
#                                Flight_ID Aeronave DepartureStation  \
# 6696    030f35839975b1721e2427db425ef402   XA-VAJ               BM
# 178553  7b9f51daca0f560676d28aee3d5666f7   XA-VAW               BM
# 53258   d4ac6f26a94efea00002147f15d96a41   XA-VIU               BM
# 123223  555496d4217768d1cc276ffbe83235d5   XA-VXF               AT
# 53248   01cb03565042d43a1deafae09eef0ca1   XA-VAN               BM
# ...                                  ...      ...              ...
# 221868  a665d50e95bf905d862563facacbf05a   XA-VXA               AO
# 92561   6dda5bd834419dd5b900408b0f5fd77b   XA-VAU               BM
# 105522  c711d31ee17b65d788d2df7ebde346f1   XA-VBI               AK
# 57082   dc6b4fa09794681fbf19cdd98f5a942e   XA-VIF               BM
# 102919  34771f9eadb3f935f45d3271fa9929ce   XA-VXP               BM
#
#        ArrivalStation     Destination_Type        Origin_Type  \
# 6696               AV  MX Amigos y Familia  Ciudad Fronteriza
# 178553             BA     Ciudad Principal  Ciudad Fronteriza
# 53258              AO     Ciudad Principal  Ciudad Fronteriza
# 123223             AU           Ecoturismo   Ciudad Principal
# 53248              AO     Ciudad Principal  Ciudad Fronteriza
# ...               ...                  ...                ...
# 221868             BM    Ciudad Fronteriza   Ciudad Principal
# 92561              AT     Ciudad Principal  Ciudad Fronteriza
# 105522             AT     Ciudad Principal              Playa
# 57082              AO     Ciudad Principal  Ciudad Fronteriza
# 102919             AT     Ciudad Principal  Ciudad Fronteriza
#
#                        STD                 STA  Capacity  Passengers  \
# 6696   2023-01-02 00:20:00 2023-01-02 05:20:00       186       120.0
# 178553 2023-01-02 00:30:00 2023-01-02 06:00:00       186       170.0
# 53258  2023-01-02 00:35:00 2023-01-02 05:30:00       186       185.0
# 123223 2023-01-02 00:55:00 2023-01-02 02:45:00       240       168.0
# 53248  2023-01-02 01:15:00 2023-01-02 06:10:00       186       165.0
# ...                    ...                 ...       ...         ...
# 221868 2023-12-31 23:00:00 2024-01-01 00:05:00       240       201.0
# 92561  2023-12-31 23:05:00 2024-01-01 04:30:00       186       131.0
# 105522 2023-12-31 23:15:00 2024-01-01 00:45:00       220       217.0
# 57082  2023-12-31 23:45:00 2024-01-01 04:40:00       186       168.0
# 102919 2023-12-31 23:50:00 2024-01-01 05:15:00       240       161.0
#
#         Bookings      Time     Route  Month  Occupation fraction
# 6696        68.0  00:20:00  BM => AV      1             0.645161
# 178553      99.0  00:30:00  BM => BA      1             0.913978
# 53258       89.0  00:35:00  BM => AO      1             0.994624
# 123223     118.0  00:55:00  AT => AU      1             0.700000
# 53248       92.0  01:15:00  BM => AO      1             0.887097
# ...          ...       ...       ...    ...                  ...
# 221868      90.0  23:00:00  AO => BM     12             0.837500
# 92561       81.0  23:05:00  BM => AT     12             0.704301
# 105522     126.0  23:15:00  AK => AT     12             0.986364
# 57082       75.0  23:45:00  BM => AO     12             0.903226
# 102919     116.0  23:50:00  BM => AT     12             0.670833
#
# [121724 rows x 15 columns]
